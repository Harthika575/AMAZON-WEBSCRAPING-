# %% [markdown]
# # WEB SCRAPPING

# %% [markdown]
# #  Import Libraries
# selenium` → Automates web browsing.
# - `BeautifulSoup` → Parses HTML to extract data.
# - `pandas` → Organizes data in tables.
# - `time`, `datetime`, `random` → Manage delays and mimic human browsing.
# - `webdriver_manager` and `Options` → Smoothly set up Chrome browser for automation.

# %%
import time, datetime, random
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# # Set  Selenium Chrome Options
# we configure how Chrome will run for scraping:
#
# - `--headless` → Runs browser in the background.
# - `--no-sandbox` & `--disable-dev-shm-usage` → Improves stability.
# - `user-agent` → Makes the browser look like a real user.
# - We also set up ChromeDriver using `webdriver.Chrome` to launch the automated browser.

# %%
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# %% [markdown]
# # Define Product Categories and URLs
# We create a dictionary called `amazon_urls` to store all the Amazon product links.
#
# - Each key represents a category like Electronics, Fashion, or Books.
# - Each value is a list of search URLs for that category.
# - This structure makes scraping organized and scalable.

# %%
amazon_urls = {
    "Electronics & Gadgets": [
        "https://www.amazon.in/s?k=smartphones",
        "https://www.amazon.in/s?k=tablets",
        "https://www.amazon.in/s?k=televisions",
        "https://www.amazon.in/s?k=projectors",
        "https://www.amazon.in/s?k=bluetooth+headphones",
        "https://www.amazon.in/s?k=power+banks",
        "https://www.amazon.in/s?k=usb+cables",
        "https://www.amazon.in/s?k=gaming+laptops",
        "https://www.amazon.in/s?k=home+theatre+systems"
    ],

    "Home & Kitchen Appliances": [
        "https://www.amazon.in/s?k=air+fryer",
        "https://www.amazon.in/s?k=microwave+oven",
        "https://www.amazon.in/s?k=otg+oven",
        "https://www.amazon.in/s?k=robotic+vacuum+cleaner",
        "https://www.amazon.in/s?k=induction+cooktop",
        "https://www.amazon.in/s?k=pressure+cooker",
        "https://www.amazon.in/s?k=rice+cooker",
        "https://www.amazon.in/s?k=food+processor",
        "https://www.amazon.in/s?k=air+cooler",
        "https://www.amazon.in/s?k=dehumidifier"
    ],

    "Fashion & Accessories": [
        "https://www.amazon.in/s?k=mens+tshirts",
        "https://www.amazon.in/s?k=jeans+for+women",
        "https://www.amazon.in/s?k=kurta+sets",
        "https://www.amazon.in/s?k=jackets",
        "https://www.amazon.in/s?k=wristwatches",
        "https://www.amazon.in/s?k=ethnic+wear",
        "https://www.amazon.in/s?k=sneakers",
        "https://www.amazon.in/s?k=leather+bags",
        "https://www.amazon.in/s?k=sunglasses",
        "https://www.amazon.in/s?k=belts"
    ],

    "Beauty & Personal Care": [
        "https://www.amazon.in/s?k=hair+straightener",
        "https://www.amazon.in/s?k=face+wash",
        "https://www.amazon.in/s?k=lipstick+set",
        "https://www.amazon.in/s?k=perfume+for+women",
        "https://www.amazon.in/s?k=mens+perfume",
        "https://www.amazon.in/s?k=skin+serum",
        "https://www.amazon.in/s?k=sunscreen",
        "https://www.amazon.in/s?k=dental+care+products",
        "https://www.amazon.in/s?k=vitamins+supplements",
        "https://www.amazon.in/s?k=fitness+watch"
    ],

    "Books & Stationery": [
        "https://www.amazon.in/s?k=fiction+books",
        "https://www.amazon.in/s?k=non+fiction+books",
        "https://www.amazon.in/s?k=comics+manga",
        "https://www.amazon.in/s?k=education+books",
        "https://www.amazon.in/s?k=art+supply",
        "https://www.amazon.in/s?k=notebooks",
        "https://www.amazon.in/s?k=pens+kits",
        "https://www.amazon.in/s?k=magazines",
        "https://www.amazon.in/s?k=board+games",
        "https://www.amazon.in/s?k=movie+dvds"
    ],

    "Grocery & Food": [
        "https://www.amazon.in/s?k=organic+snacks",
        "https://www.amazon.in/s?k=coffee+powder",
        "https://www.amazon.in/s?k=tea+leaves",
        "https://www.amazon.in/s?k=spices+masala",
        "https://www.amazon.in/s?k=health+protein+powder",
        "https://www.amazon.in/s?k=almonds+nuts",
        "https://www.amazon.in/s?k=cookies+biscuit",
        "https://www.amazon.in/s?k=breakfast+cereal",
        "https://www.amazon.in/s?k=keto+foods",
        "https://www.amazon.in/s?k=energy+bars"
    ],

    "Baby, Kids & Toys": [
        "https://www.amazon.in/s?k=diapers",
        "https://www.amazon.in/s?k=school+bags",
        "https://www.amazon.in/s?k=toy+cars",
        "https://www.amazon.in/s?k=lego+sets",
        "https://www.amazon.in/s?k=puzzle+games",
        "https://www.amazon.in/s?k=baby+clothing",
        "https://www.amazon.in/s?k=strollers",
        "https://www.amazon.in/s?k=baby+toys",
        "https://www.amazon.in/s?k=kids+footwear",
        "https://www.amazon.in/s?k=baby+care+essentials"
    ],

    "Automotive & Outdoor": [
        "https://www.amazon.in/s?k=car+accessories",
        "https://www.amazon.in/s?k=bike+lights",
        "https://www.amazon.in/s?k=tool+kit",
        "https://www.amazon.in/s?k=power+tools",
        "https://www.amazon.in/s?k=garden+tools",
        "https://www.amazon.in/s?k=garden+hose",
        "https://www.amazon.in/s?k=outdoor+lamp",
        "https://www.amazon.in/s?k=camping+gear",
        "https://www.amazon.in/s?k=fishing+kit",
        "https://www.amazon.in/s?k=car+cleaner+kit"
    ]
}

# %% [markdown]
# # Initialize Containers for Scraped Data
# create empty lists to store all the details we want to scrape:
#
# - `categories`, `names`, `prices`, `ratings`, `reviews`, `boughts_last_month`, `offers`, `org_prices`
# - `num_pages_to_scrape` defines how many pages we will scrape per product URL.
# - These lists act as storage for our collected data.

# %%
categories, names, prices, ratings, reviews, boughts_last_month, offers, org_prices = [], [], [], [], [], [], [], []

num_pages_to_scrape = 1

# %% [markdown]
# This is the main scraping loop:
#
# 1. Loops through each category and its URLs.
# 2. Opens each page using Selenium and parses it with BeautifulSoup.
# 3. Saves HTML pages for debugging.
# 4. Checks for errors like "503 Service Unavailable" and skips problematic pages.
# 5. Extracts product details — name, price, rating, reviews, offers, and boughts last month.
# 6. Appends all collected data into the respective lists.
# 7. Prints progress after scraping each page.

# %%
total_categories = len(amazon_urls.keys())
current_category_count = 0
for category, base_urls in amazon_urls.items():
    current_category_count += 1
    url_count = 0
    for base_url in base_urls:
        url_count += 1
        total_category_urls = len(base_urls)
        for page_index in range(num_pages_to_scrape):
            if page_index != 1:
                url = base_url + f"&page={str(page_index+1)}"
            else:
                url = base_url
            driver.get(url)
            time.sleep(random.randint(5, 10))

            soup = BeautifulSoup(driver.page_source, "html.parser")

            with open(f"cat_{current_category_count}_soup_page_{page_index}.html", "w", encoding="utf-8") as f:
                f.write(soup.prettify())

            text_to_find = "503 - Service Unavailable Error"
            with open(f"soup_page_{page_index}.html", "r", encoding="utf-8") as f:
                content = f.read()
                if text_to_find in content:
                    print(f"Skipping Page {page_index} ==> ", text_to_find)
                    continue

            products = soup.select('div[data-component-type="s-search-result"]')

            for prod in products:
                categories.append(category)
                name = prod.select_one("h2 span:not([class])")
                names.append(name.text.strip() if name else "N/A")

                price = prod.select_one("span.a-price-whole")
                prices.append(price.text.strip() if price else "N/A")

                rating = prod.select_one("span.a-icon-alt")
                ratings.append(rating.text.strip() if rating else "N/A")

                price_block = prod.select_one('div[data-cy="price-recipe"]')
                if not price_block:
                    offers.append("N/A")
                    org_prices.append("N/A")
                else:
                    offs = price_block.select("span:not([class])")
                    offer_text = ""
                    for ofr in offs:
                        text = ofr.get_text(strip=True)
                        if r"% off" in text:
                            offer_text = text.strip("()")
                            break
                    offers.append(offer_text if offer_text else "N/A")

                    org_price = prod.select_one("span.a-offscreen")
                    org_prices.append(org_price.text.replace("₹", "").strip() if org_price else "N/A")

                review_block = prod.select_one('div[data-cy="reviews-block"]')
                if not review_block:
                    reviews.append("N/A")
                    boughts_last_month.append("N/A")
                else:
                    review = review_block.find('span', class_=('a-size-base s-underline-text'))
                    reviews.append(review.text.strip() if review else "N/A")

                    bought_last_month = review_block.find('span', class_=['a-size-base a-color-secondary'])
                    boughts_last_month.append(bought_last_month.text.strip() if bought_last_month else "N/A")

            print(f"Category ({current_category_count}/{total_categories}): {category} , url ({url_count}/{total_category_urls}) ✅ Page {page_index+1} scraped, {len(products)} newly added, total rows so far: {len(names)}, url: {url}")
# Out:
# Category (1/8): Electronics & Gadgets , url (1/9) ✅ Page 1 scraped, 22 newly added, total rows so far: 22, url: https://www.amazon.in/s?k=smartphones&page=1
# Category (1/8): Electronics & Gadgets , url (2/9) ✅ Page 1 scraped, 16 newly added, total rows so far: 38, url: https://www.amazon.in/s?k=tablets&page=1
# Category (1/8): Electronics & Gadgets , url (3/9) ✅ Page 1 scraped, 22 newly added, total rows so far: 60, url: https://www.amazon.in/s?k=televisions&page=1
# Category (1/8): Electronics & Gadgets , url (4/9) ✅ Page 1 scraped, 16 newly added, total rows so far: 76, url: https://www.amazon.in/s?k=projectors&page=1
# Category (1/8): Electronics & Gadgets , url (5/9) ✅ Page 1 scraped, 16 newly added, total rows so far: 92, url: https://www.amazon.in/s?k=bluetooth+headphones&page=1
# Category (1/8): Electronics & Gadgets , url (6/9) ✅ Page 1 scraped, 22 newly added, total rows so far: 114, url: https://www.amazon.in/s?k=power+banks&page=1
# Category (1/8): Electronics & Gadgets , url (7/9) ✅ Page 1 scraped, 16 newly added, total rows so far: 130, url: https://www.amazon.in/s?k=usb+cables&page=1
# Category (1/8): Electronics & Gadgets , url (8/9) ✅ Page 1 scraped, 16 newly added, total rows so far: 146, url: https://www.amazon.in/s?k=gaming+laptops&page=1
# Category (1/8): Electronics & Gadgets , url (9/9) ✅ Page 1 scraped, 16 newly added, total rows so far: 162, url: https://www.amazon.in/s?k=home+theatre+systems&page=1
# Category (2/8): Home & Kitchen Appliances , url (1/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 178, url: https://www.amazon.in/s?k=air+fryer&page=1
# Category (2/8): Home & Kitchen Appliances , url (2/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 194, url: https://www.amazon.in/s?k=microwave+oven&page=1
# Category (2/8): Home & Kitchen Appliances , url (3/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 210, url: https://www.amazon.in/s?k=otg+oven&page=1
# Category (2/8): Home & Kitchen Appliances , url (4/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 226, url: https://www.amazon.in/s?k=robotic+vacuum+cleaner&page=1
# Category (2/8): Home & Kitchen Appliances , url (5/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 242, url: https://www.amazon.in/s?k=induction+cooktop&page=1
# Category (2/8): Home & Kitchen Appliances , url (6/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 290, url: https://www.amazon.in/s?k=pressure+cooker&page=1
# Category (2/8): Home & Kitchen Appliances , url (7/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 306, url: https://www.amazon.in/s?k=rice+cooker&page=1
# Category (2/8): Home & Kitchen Appliances , url (8/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 322, url: https://www.amazon.in/s?k=food+processor&page=1
# Category (2/8): Home & Kitchen Appliances , url (9/10) ✅ Page 1 scraped, 22 newly added, total rows so far: 344, url: https://www.amazon.in/s?k=air+cooler&page=1
# Category (2/8): Home & Kitchen Appliances , url (10/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 360, url: https://www.amazon.in/s?k=dehumidifier&page=1
# Category (3/8): Fashion & Accessories , url (1/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 420, url: https://www.amazon.in/s?k=mens+tshirts&page=1
# Category (3/8): Fashion & Accessories , url (2/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 480, url: https://www.amazon.in/s?k=jeans+for+women&page=1
# Category (3/8): Fashion & Accessories , url (3/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 528, url: https://www.amazon.in/s?k=kurta+sets&page=1
# Category (3/8): Fashion & Accessories , url (4/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 576, url: https://www.amazon.in/s?k=jackets&page=1
# Category (3/8): Fashion & Accessories , url (5/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 624, url: https://www.amazon.in/s?k=wristwatches&page=1
# Category (3/8): Fashion & Accessories , url (6/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 672, url: https://www.amazon.in/s?k=ethnic+wear&page=1
# Category (3/8): Fashion & Accessories , url (7/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 720, url: https://www.amazon.in/s?k=sneakers&page=1
# Category (3/8): Fashion & Accessories , url (8/10) ✅ Page 1 scraped, 22 newly added, total rows so far: 742, url: https://www.amazon.in/s?k=leather+bags&page=1
# Category (3/8): Fashion & Accessories , url (9/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 790, url: https://www.amazon.in/s?k=sunglasses&page=1
# Category (3/8): Fashion & Accessories , url (10/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 838, url: https://www.amazon.in/s?k=belts&page=1
# Category (4/8): Beauty & Personal Care , url (1/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 886, url: https://www.amazon.in/s?k=hair+straightener&page=1
# Category (4/8): Beauty & Personal Care , url (2/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 934, url: https://www.amazon.in/s?k=face+wash&page=1
# Category (4/8): Beauty & Personal Care , url (3/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 982, url: https://www.amazon.in/s?k=lipstick+set&page=1
# Category (4/8): Beauty & Personal Care , url (4/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1030, url: https://www.amazon.in/s?k=perfume+for+women&page=1
# Category (4/8): Beauty & Personal Care , url (5/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 1090, url: https://www.amazon.in/s?k=mens+perfume&page=1
# Category (4/8): Beauty & Personal Care , url (6/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1138, url: https://www.amazon.in/s?k=skin+serum&page=1
# Category (4/8): Beauty & Personal Care , url (7/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1186, url: https://www.amazon.in/s?k=sunscreen&page=1
# Category (4/8): Beauty & Personal Care , url (8/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1234, url: https://www.amazon.in/s?k=dental+care+products&page=1
# Category (4/8): Beauty & Personal Care , url (9/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1282, url: https://www.amazon.in/s?k=vitamins+supplements&page=1
# Category (4/8): Beauty & Personal Care , url (10/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 1298, url: https://www.amazon.in/s?k=fitness+watch&page=1
# Category (5/8): Books & Stationery , url (1/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 1314, url: https://www.amazon.in/s?k=fiction+books&page=1
# Category (5/8): Books & Stationery , url (2/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 1330, url: https://www.amazon.in/s?k=non+fiction+books&page=1
# Category (5/8): Books & Stationery , url (3/10) ✅ Page 1 scraped, 22 newly added, total rows so far: 1352, url: https://www.amazon.in/s?k=comics+manga&page=1
# Category (5/8): Books & Stationery , url (4/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 1368, url: https://www.amazon.in/s?k=education+books&page=1
# Category (5/8): Books & Stationery , url (5/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 1428, url: https://www.amazon.in/s?k=art+supply&page=1
# Category (5/8): Books & Stationery , url (6/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1476, url: https://www.amazon.in/s?k=notebooks&page=1
# Category (5/8): Books & Stationery , url (7/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 1536, url: https://www.amazon.in/s?k=pens+kits&page=1
# Category (5/8): Books & Stationery , url (8/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 1552, url: https://www.amazon.in/s?k=magazines&page=1
# Category (5/8): Books & Stationery , url (9/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 1612, url: https://www.amazon.in/s?k=board+games&page=1
# Category (5/8): Books & Stationery , url (10/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 1628, url: https://www.amazon.in/s?k=movie+dvds&page=1
# Category (6/8): Grocery & Food , url (1/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1676, url: https://www.amazon.in/s?k=organic+snacks&page=1
# Category (6/8): Grocery & Food , url (2/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1724, url: https://www.amazon.in/s?k=coffee+powder&page=1
# Category (6/8): Grocery & Food , url (3/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1772, url: https://www.amazon.in/s?k=tea+leaves&page=1
# Category (6/8): Grocery & Food , url (4/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1820, url: https://www.amazon.in/s?k=spices+masala&page=1
# Category (6/8): Grocery & Food , url (5/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 1868, url: https://www.amazon.in/s?k=health+protein+powder&page=1
# Category (6/8): Grocery & Food , url (6/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 1928, url: https://www.amazon.in/s?k=almonds+nuts&page=1
# Category (6/8): Grocery & Food , url (7/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 1988, url: https://www.amazon.in/s?k=cookies+biscuit&page=1
# Category (6/8): Grocery & Food , url (8/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2036, url: https://www.amazon.in/s?k=breakfast+cereal&page=1
# Category (6/8): Grocery & Food , url (9/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2084, url: https://www.amazon.in/s?k=keto+foods&page=1
# Category (6/8): Grocery & Food , url (10/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 2144, url: https://www.amazon.in/s?k=energy+bars&page=1
# Category (7/8): Baby, Kids & Toys , url (1/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2192, url: https://www.amazon.in/s?k=diapers&page=1
# Category (7/8): Baby, Kids & Toys , url (2/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 2252, url: https://www.amazon.in/s?k=school+bags&page=1
# Category (7/8): Baby, Kids & Toys , url (3/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 2312, url: https://www.amazon.in/s?k=toy+cars&page=1
# Category (7/8): Baby, Kids & Toys , url (4/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2360, url: https://www.amazon.in/s?k=lego+sets&page=1
# Category (7/8): Baby, Kids & Toys , url (5/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2408, url: https://www.amazon.in/s?k=puzzle+games&page=1
# Category (7/8): Baby, Kids & Toys , url (6/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2456, url: https://www.amazon.in/s?k=baby+clothing&page=1
# Category (7/8): Baby, Kids & Toys , url (7/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 2472, url: https://www.amazon.in/s?k=strollers&page=1
# Category (7/8): Baby, Kids & Toys , url (8/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 2532, url: https://www.amazon.in/s?k=baby+toys&page=1
# Category (7/8): Baby, Kids & Toys , url (9/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2580, url: https://www.amazon.in/s?k=kids+footwear&page=1
# Category (7/8): Baby, Kids & Toys , url (10/10) ✅ Page 1 scraped, 60 newly added, total rows so far: 2640, url: https://www.amazon.in/s?k=baby+care+essentials&page=1
# Category (8/8): Automotive & Outdoor , url (1/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2688, url: https://www.amazon.in/s?k=car+accessories&page=1
# Category (8/8): Automotive & Outdoor , url (2/10) ✅ Page 1 scraped, 16 newly added, total rows so far: 2704, url: https://www.amazon.in/s?k=bike+lights&page=1
# Category (8/8): Automotive & Outdoor , url (3/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2752, url: https://www.amazon.in/s?k=tool+kit&page=1
# Category (8/8): Automotive & Outdoor , url (4/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2800, url: https://www.amazon.in/s?k=power+tools&page=1
# Category (8/8): Automotive & Outdoor , url (5/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2848, url: https://www.amazon.in/s?k=garden+tools&page=1
# Category (8/8): Automotive & Outdoor , url (6/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2896, url: https://www.amazon.in/s?k=garden+hose&page=1
# Category (8/8): Automotive & Outdoor , url (7/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2944, url: https://www.amazon.in/s?k=outdoor+lamp&page=1
# Category (8/8): Automotive & Outdoor , url (8/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 2992, url: https://www.amazon.in/s?k=camping+gear&page=1
# Category (8/8): Automotive & Outdoor , url (9/10) ✅ Page 1 scraped, 22 newly added, total rows so far: 3014, url: https://www.amazon.in/s?k=fishing+kit&page=1
# Category (8/8): Automotive & Outdoor , url (10/10) ✅ Page 1 scraped, 48 newly added, total rows so far: 3062, url: https://www.amazon.in/s?k=car+cleaner+kit&page=1

# %% [markdown]
#  Close the Selenium Browser

# %%
driver.quit()

# %% [markdown]
# Once all data is collected:
#
# 1. We organize the scraped lists into a dictionary called `data`.
# 2. Convert it into a `pandas DataFrame` for structured analysis.
# 3. Print the total number of rows collected to verify our scraping results.

# %%
data = {
    "Category": categories,
    "Name": names,
    "Price (INR)": prices,
    "Rating": ratings,
    "Reviews (Nos)": reviews,
    "Bought Last Month": boughts_last_month,
    "Offer": offers,
    
}

df = pd.DataFrame(data)
print("Total rows collected:", len(df))
# Out:
# Total rows collected: 3062

# %%
raw_data_len = df.shape[0]
df = df.drop_duplicates()
final_data_len = df.shape[0]
print(f"{raw_data_len - final_data_len} duplicates found & removed, Finally {final_data_len} rows available")

filename = f"amazon_beauty_{len(df)}_{datetime.datetime.now().strftime('%Y-%m-%d %H_%M_%S')}.csv"
df.to_csv(filename, index=False)
# Out:
# 71 duplicates found & removed, Finally 2991 rows available
